# %%
import json
import sys

# %%
with open(file='label_out_trump_from_meloni.json', mode='r') as file:
    labels = json.load(file)

labels
# Out:
# [{'image': 'LP_22940570.jpg', 'annotations': ['Trump']},
#  {'image': 'LP_22940575.jpg', 'annotations': ['Trump']},
#  {'image': 'LP_22940576.jpg', 'annotations': ['Trump']},
#  {'image': 'LP_22940577.jpg', 'annotations': ['Trump']},
#  {'image': 'LP_22940578.jpg', 'annotations': ['Trump']},
#  {'image': 'LP_23007419.jpg', 'annotations': ['Trump']},
#  {'image': 'LP_23007420.jpg', 'annotations': ['Trump']},
#  {'image': 'LP_23007421.jpg', 'annotations': ['Trump']},
#  {'image': 'LP_23007422.jpg', 'annotations': ['Trump']},
#  {'image': 'LP_23007423.jpg', 'annotations': ['Trump']},
#  {'image': 'LP_23007424.jpg', 'annotations': ['Trump']},
#  {'image': 'LP_23007425.jpg', 'annotations': ['Trump']},
#  {'image': 'LP_23299285.jpg', 'annotations': ['Only Trump']},
#  {'image': 'LP_23299286.jpg', 'annotations': ['Only Trump']},
#  {'image': 'LP_23299287.jpg', 'annotations': ['Trump']},
#  {'image': 'LP_23299288.jpg', 'annotations': ['Only Trump']},
# ...

# %%
start_dir = './Unclean Data Meloni'
dest_dir = './Trump temp op'

# %%
# list images that include Only Trump annotation
only_trump_images = [label['image'] for label in labels if 'Only Trump' in label['annotations']]

# %%
# cut and paste images in the images from one dir to another
for image in only_trump_images:
    if

# %%
only_trump_images
# Out:
# ['LP_23299285.jpg',
#  'LP_23299286.jpg',
#  'LP_23299288.jpg',
#  'LP_23299290.jpg',
#  'LP_23299292.jpg',
#  'LP_23299293.jpg',
#  'LP_23299297.jpg',
#  'LP_23299304.jpg',
#  'LP_23299306.jpg',
#  'LP_23299307.jpg',
#  'LP_23299308.jpg',
#  'LP_23299310.jpg',
#  'LP_23299311.jpg',
#  'LP_23299312.jpg',
#  'LP_23299314.jpg',
#  'LP_23299551.jpg',
#  'LP_23299552.jpg',
#  'LP_23299557.jpg',
#  'LP_23299558.jpg',
#  'LP_23299563.jpg',
#  'LP_23299565.jpg',
#  'LP_23299572.jpg']
